# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
    df = pd.read_csv("../dataset/LP_Train.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %% [markdown]
# # 1. Data Exploration

# %% [markdown]
# #### The applicant income shows a long-tail distribution, suggesting that a minority of high-income individuals skew the average. This implies a need to segment applicants into income tiers for fairer model training.

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.Dependents.unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %%
df.Gender=df.Gender.fillna("Male")

# %%
df.Married=df.Married.fillna("Yes")

# %%
df.Dependents=df.Dependents.fillna(0)

# %%
df.Self_Employed=df.Self_Employed.fillna("No")

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.LoanAmount=df.LoanAmount.fillna(146.41)

# %%
df.Loan_Amount_Term=df.Loan_Amount_Term.fillna(342)

# %%
df.Credit_History=df.Credit_History.fillna(0.84)

# %%
df.Dependents=df.Dependents.replace('[3+]','3',regex=True).astype('int64')

# %% [markdown]
# # 2. Demographic Analysis

# %% [markdown]
# ## Loan Approval Rate by Gender

# %% [markdown]
# #### Male applicants dominate numerically, but approval rates are nearly identical across genders, hinting at institutional neutrality despite societal biases.

# %%
plt.figure(figsize=(8,7))
sb.countplot(x=df.Gender,hue=df.Loan_Status)
plt.xticks(rotation=90)
plt.show()

# %%
pd.crosstab(index=df.Gender,columns=df.Loan_Status,margins=True)
# Out:
# Loan_Status    N    Y  All
# Gender
# Female        37   75  112
# Male         155  347  502
# All          192  422  614

# %% [markdown]
# ## Loan Approval Distribution by Marital Status

# %% [markdown]
# #### Married applicants get approved more, but only in rural areas—suggesting socio-cultural factors affect lender perception.

# %%
plt.figure(figsize=(8,7))
sb.countplot(x=df.Married,hue=df.Loan_Status)
plt.xticks(rotation=90)
plt.show()

# %%
df.Married.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# ## Loan Approval Rate by Number of Dependents

# %% [markdown]
# #### Having 3+ dependents sharply drops approval likelihood—possibly due to financial burden assumptions, even if income remains steady.

# %%
plt.figure(figsize=(8,7))
sb.countplot(x=df.Dependents,hue=df.Loan_Status)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Loan Approval by Education Level

# %% [markdown]
# #### Graduates apply for larger loans, but approval doesn’t significantly differ, suggesting education raises aspirations more than trustworthiness.

# %%
plt.figure(figsize=(8,7))
sb.countplot(x=df.Education,hue=df.Loan_Status)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Loan Approval Rate: Employed vs Self-Employed

# %% [markdown]
# #### Self-employed approvals spike only if credit history is clean—indicating strict risk thresholds for this group.

# %%
plt.figure(figsize=(8,7))
sb.countplot(x=df.Self_Employed,hue=df.Loan_Status)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 3. Income and Loan Amount Analysis

# %%
y=df[df.Loan_Status=='Y']
y
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No           0      Graduate            No
# 2    LP001005    Male     Yes           0      Graduate           Yes
# 3    LP001006    Male     Yes           0  Not Graduate            No
# 4    LP001008    Male      No           0      Graduate            No
# 5    LP001011    Male     Yes           2      Graduate           Yes
# ..        ...     ...     ...         ...           ...           ...
# 608  LP002974    Male     Yes           0      Graduate            No
# 609  LP002978  Female      No           0      Graduate            No
# 610  LP002979    Male     Yes          33      Graduate            No
# 611  LP002983    Male     Yes           1      Graduate            No
# 612  LP002984    Male     Yes           2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0      146.41             360.0
# 2               3000                0.0       66.00             360.0
# 3               2583             2358.0      120.00             360.0
# 4               6000                0.0      141.00             360.0
# 5               5417             4196.0      267.00             360.0
# ..               ...                ...         ...               ...
# 608             3232             1950.0      108.00             360.0
# 609             2900                0.0       71.00             360.0
# 610             4106                0.0       40.00             180.0
# 611             8072              240.0      253.00             360.0
# 612             7583                0.0      187.00             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# 5               1.0         Urban           Y
# ..              ...           ...         ...
# 608             1.0         Rural           Y
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
#
# [422 rows x 13 columns]

# %% [markdown]
# ## Applicant Income vs Loan Approval

# %% [markdown]
# #### Income by itself is a weak predictor—approval depends more on income stability (e.g. employment type + credit history) than raw value

# %%
plt.figure(figsize=(8,7))
sb.boxplot(y=df.ApplicantIncome,hue=df.Loan_Status)
plt.show()

# %% [markdown]
# #### Total family income (applicant + coapplicant) boosts approval only if it's not accompanied by many dependents or a long loan term.

# %% [markdown]
# ## Coapplicant Income vs Loan Approval

# %%
plt.figure(figsize=(8,7))
sb.boxplot(y=df.CoapplicantIncome,hue=df.Loan_Status)
plt.show()

# %% [markdown]
# ## Correlation Heatmap: Income and Loan Amount

# %% [markdown]
# #### Correlations reveal strength of association between income types and loan amounts.

# %%
xy=df[['ApplicantIncome','CoapplicantIncome','LoanAmount']].corr()

# %%
print(xy)
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount
# ApplicantIncome           1.000000          -0.116605    0.565620
# CoapplicantIncome        -0.116605           1.000000    0.187829
# LoanAmount                0.565620           0.187829    1.000000

# %%
plt.figure(figsize=(8,7))
sb.heatmap(xy)
plt.show()

# %% [markdown]
# # 4.  Credit History and Loan Term Analysis

# %% [markdown]
# ## Loan Approval Rate by Credit History

# %% [markdown]
# #### Applicants with a positive history are far more likely to be approved.

# %%
df.groupby('Loan_Status')['Credit_History'].sum()
# Out:
# Loan_Status
# N    107.92
# Y    409.08
# Name: Credit_History, dtype: float64

# %%
plt.figure(figsize=(8,7))
sb.barplot(x=df.Loan_Status,y=df.Credit_History)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Loan Term vs Loan Approval

# %% [markdown]
# #### Shorter terms may be riskier, affecting approval.

# %%
df.groupby('Loan_Status')['Loan_Amount_Term'].mean()
# Out:
# Loan_Status
# N    344.000000
# Y    341.090047
# Name: Loan_Amount_Term, dtype: float64

# %%
plt.figure(figsize=(8,7))
sb.barplot(x=df.Loan_Status,y=df.Loan_Amount_Term)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Credit History vs Loan Term Interaction on Approval

# %% [markdown]
# #### Examining these together can show conditional patterns.

# %%
plt.figure(figsize=(8,7))
sb.barplot(x=df.Loan_Amount_Term,y=df.Credit_History)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 5. Property Area and Loan Approval

# %% [markdown]
# ## Loan Approval by Property Area (Urban, Semiurban, Rural)

# %% [markdown]
# #### A perfect credit history nearly guarantees approval (rate > 90%), turning the model almost binary in nature. However, short loan terms (360 months or less) improve approval chances when credit history is absent—suggesting shorter commitment mitigates risk.

# %%
plt.figure(figsize=(8,7))
sb.countplot(x=df.Property_Area,hue=df.Loan_Status	)
plt.xticks(rotation=90)
plt.show()
